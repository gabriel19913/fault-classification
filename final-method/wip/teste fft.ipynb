# %%
import scipy.io as sio
import matplotlib.pyplot as plt
import plotly.io as pio
pio.renderers.default = 'iframe' # or 'notebook' or 'colab'

SAMPLE_SIGNAL = '/home/gabriel/Documentos/projects/mestrado/fault-classification/data/detected_signals/detected_sim_Chesf_500_Classifier_LOC3_AB_20_0_1.0000.mat'
mat = sio.loadmat(SAMPLE_SIGNAL)

# %%
mat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'V_nom', 'I_nom', 'V_index', 'I_index', 'V_det', 'I_det', 'faultType', 'fs'])

# %%
mat['I_nom'][:,2].shape
# Out:
# (5632,)

# %%
plt.plot(mat['I_nom'][:,2])
plt.show()

# %%
import plotly.graph_objects as go
from scipy.fft import rfft, rfftfreq
import numpy as np

yf = rfft(mat['I_nom'][:,2])
xf = rfftfreq(mat['I_nom'][:,2].shape[0], 1 / 15360)

fig = go.Figure(data=go.Scatter(x=xf, y=np.abs(yf)))
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_10.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plt.plot(mat['I_det'][:,2])
plt.show()

# %%
data = mat['I_det'][:,2]

# %%
data.shape
# Out:
# (384,)

# %%
yf = rfft(data)
xf = rfftfreq(data.shape[0], 1 / 15360)

fig = go.Figure(data=go.Scatter(x=xf, y=np.abs(yf)))
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_14.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
512 - 384
# Out:
# 128

# %%
new_data = np.concatenate((data, np.zeros(128)))

# %%
yf = rfft(new_data)
xf = rfftfreq(new_data.shape[0], 1 / 15360)

fig = go.Figure(data=go.Scatter(x=xf, y=np.abs(yf)))
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_17.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
